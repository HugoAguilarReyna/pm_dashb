# %%
mongodb+srv://<db_username>:<db_password>@clusteract1.kpdhd5e.mongodb.net/

mongodb+srv://aguilarhugo55_db_user:c5mfG11QT68ib4my@<clusteract1>/tesina_dashboard_atlas?retryWrites=true&w=majority

ClusterAct1


dash_pm

project_manager

mongodb+srv://aguilarhugo55_db_user:c5mfG11QT68ib4my@clusteract1.kpdhd5e.mongodb.net/?appName=ClusterAct1


D:\Github\Dashboard_PM> docker-compose up --build
